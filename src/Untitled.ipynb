# %%
import firewxpy.observations.upper_air.profiles as observed_vertical_profiles
#import firewxpy.observations.upper_air.soundings as observed_soundings

# %%
observed_vertical_profiles.plot_relative_humidity_wind_profile('panc')
# Out:
# Saved PANC.png sounding to FireWxPy Graphics/Observations/Upper Air/Relative Humidity Wind Profiles.

# %%
#observed_soundings.plot_observed_sounding('nkx')

# %%
#observed_vertical_profiles.plot_temperature_relative_humidity_wind_profile('panc')
