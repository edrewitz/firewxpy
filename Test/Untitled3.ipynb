# %%
from fuels_graphics import create_psa_100hr_fuels_charts

# %%
create_psa_100hr_fuels_charts('oscc', start_date='2009-01-01', data=True)
# Out:
# 100-HR Fuels Charts Saved To f:Fuels Maps/OSCC/100HR DEAD FUEL
