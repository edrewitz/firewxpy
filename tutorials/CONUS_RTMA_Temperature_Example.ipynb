# %%
# IMPORT THE RTMA CONUS MODULE OF FIREWXPY
from firewxpy import rtma_conus as rtma

# %%
'''
In this example we will use FireWxPy to download, parse and plot the latest Real Time Mesoscale Analysis (RTMA)
data for CONUS aka "The Lower-48." The default area if the user does not set any value for state or gacc_region is 
CONUS. 

If the user doesn't pass any data into the function, the function will download and unpack the data automatically. 
This example we will only make 2 plots so we won't download the data outside the function and pass it in. 

NOTE: If the user wants to make a lot of graphics in an automated script, the recommended method is to download
the data outside of the function and pass it in. The function will unpack and parse the data the user passes in. 
The reason that downloading the data outside of the function and passing it in for users who wish to create a lot
of graphics is recommended is to minimize the amount of data requests on the servers which the data gets downloaded
from. 

This example will also simulate a first time user to show how FireWxPy builds itself when it comes to the directory
and making sure all the necessary files are downloaded and placed where they need to be. 

FireWxPy will download, unzip and file all the needed .SHP files and their components 
FireWxPy will also create a folder called "Weather Data", this Weather Data folder is the parent directory for
where all the graphics will be saved to. Anytime a user adds a new graphic, FireWxPy will automatically build
the new branch for the new graphic. The beauty of this software is no manual set up is needed for downloading, 
unzipping and filing shapefiles as well as setting up the directory that will store the weather graphics. 

My motto is: I want my software to do all the work so you don't have to! 

The FireWxPy package is developed by USFS Predictive Services Meteorologist Eric J. Drewitz (@FireWxGuy on bluesky.social)

'''

rtma.plot_temperature()
rtma.plot_24_hour_temperature_comparison()
# Out:
# NWS CWA Boundaries folder does not exist!
# Will Download the files and create a new folder automatically.
# Downloading...
# Success!
# NWS Fire Weather Zones folder does not exist!
# Will Download the files and create a new folder automatically.
# Downloading...
# Success!
# NWS Public Zones folder does not exist!
# Will Download the files and create a new folder automatically.
# Downloading...
# Success!
# GACC Boundaries Shapefiles folder does not exist!
# Will Download the files and create a new folder automatically.
# Downloading...
# Success!
# PSA Shapefiles folder does not exist!
# Will Download the files and create a new folder automatically.
# Downloading...
# Shapefile imported successfully!
# Already Satisfied: NWS CWA Boundaries folder exists.
# Already Satisfied: NWS Fire Weather Zones folder exists.
# Already Satisfied: NWS Public Zones folder exists.
# Already Satisfied: GACC Boundaries Shapefiles folder exists.
# Already Satisfied: PSA Shapefiles folder exists.
# ...
