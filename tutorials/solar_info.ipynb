# %%
# Imports the plot_daily_solar_information from firewxpy
from firewxpy import plot_daily_solar_information

# %%
'''
In this example we will create a solar information graphic using firewxpy. 
The user must input the latitude/longitude coordinates in decimal degrees format:

plot_daily_solar_information(latitude, longitude)

For latitude: (+/-) represents the (Northern/Southern) Hemisphere
For longitude: (-/+) represents the (Western/Eastern) Hemisphere

In this example we will enter the coordinates for Riverside, California: 33.9806N/117.3755W

Now time to make the plot!

'''
plot_daily_solar_information(33.9806, -117.3755)
# Out:
# Creating Image - Please Wait...
# Already Satisfied: f:Weather Data exists.
# f:Weather Data does not exist. Building the new branch...
# Successfully built new branch
# Image saved to: Weather Data/Solar Information/33.9806N_117.3755W_SolarInfo.png
