# %%
#IMPORTS THE NEEDED CLASS
from firewxpy import nws_relative_humidity_forecast

# %%
'''
In this example we will make 3 plots for the state of Arizona: 1) Low Minimum RH Forecast
                                                               2) Poor Overnight RH Recovery Forecast
                                                               3) Excellent Overnight RH Recovery Forecast

These functions all have a default value which defines what constitutes low minimum rh, a poor and excellent 
overnight rh recovery. The default values are based on Southern California Criteria so users in other regions,
be sure to change them to fit the criteria for your area. What works in Southern California won't work in 
New York and visa versa. 

The default values for low minimum rh = 15%, poor overnight recovery = 30% and excellent overnight recovery = 80%. 

In this example we will keep the defaults for low minimum rh and poor overnight recovery, however we will change
the threshold for an excellent overnight recovery from 80% to 70%. Since we are only making 3 plots, we won't 
download the data outside of the function and pass it in, though if the user wishes to make a lot of graphics in
a script, then downloading the graphics outside of the function and passing them in is the recommended method to 
reduce the amount of data requests on the server. Please refer to my Texas example on how to do that. 

Now let's make our plots!

P.S. Disregard that image at the bottom, sometimes jupyter notebooks will show a bogus image after the image saves. 
The images in the folder have the signature text box displayed in the correct place so that image at the bottom
is erroneous. 
'''
nws_relative_humidity_forecast.plot_low_minimum_relative_humidity_forecast(state='az')
nws_relative_humidity_forecast.plot_poor_overnight_recovery_relative_humidity_forecast(state='az')
nws_relative_humidity_forecast.plot_excellent_overnight_recovery_relative_humidity_forecast(excellent_overnight_recovery_rh_threshold=70, state='az')
# Out:
# Already Satisfied: NWS CWA Boundaries folder exists.
# Already Satisfied: NWS Fire Weather Zones folder exists.
# Already Satisfied: NWS Public Zones folder exists.
# Already Satisfied: GACC Boundaries Shapefiles folder exists.
# Already Satisfied: PSA Shapefiles folder exists.
# Shapefile imported successfully!
# Already Satisfied: NWS CWA Boundaries folder exists.
# Already Satisfied: NWS Fire Weather Zones folder exists.
# Already Satisfied: NWS Public Zones folder exists.
# Already Satisfied: GACC Boundaries Shapefiles folder exists.
# Already Satisfied: PSA Shapefiles folder exists.
# Shapefile imported successfully!
# Already Satisfied: NWS CWA Boundaries folder exists.
# Already Satisfied: NWS Fire Weather Zones folder exists.
# Already Satisfied: NWS Public Zones folder exists.
# Already Satisfied: GACC Boundaries Shapefiles folder exists.
# Already Satisfied: PSA Shapefiles folder exists.
# Already Satisfied: CWA Shapefile Exists.
# Shapefiles extracted successfully!
# ...
