# %%
# IMPORT THE PLOT_OBSERVED_SOUNDING FUNCTION FROM FIREWXPY
from firewxpy import plot_observed_sounding

# %%
'''
In this example we will use FireWxPy to download and plot the latest observed sounding data from San Diego, CA 
(NKX). The sounding plots also show comparisons for the previous day. It is currently 9/21/2024 6:50pm PDT (0150 UTC)
which means we will download the 9/21/2024 00z sounding and the comparisons will show how 9/21/2024 00z compares
to 9/20/2024 00z. 

The only value the user must pass into the function is the abbreviation for the upper-air site (must be a string!)

Now let's plot our sounding!
'''
plot_observed_sounding('nkx')
# Out:
# NKX 09/22/2024 00:00 UTC data retrieved successfully!
# NKX 09/21/2024 00:00 UTC data retrieved successfully!
# Already Satisfied: Weather Data folder exists.
# f:Weather Data/Soundings does not exist.
# Building Soundings branch...
# Successfully built new branch to directory!
# NKX Sounding Saved to Weather Data/Soundings/NKX.png
