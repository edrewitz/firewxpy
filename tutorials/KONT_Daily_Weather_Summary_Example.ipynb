# %%
# IMPORT OUR GRAPHICAL DAILY WEATHER SUMMARY FUNCTION
from firewxpy import graphical_daily_summary

# %%
'''
In this example we will make our daily graphical weather summary for an ASOS site. 
The FireWxPy daily weather summaries include: 1) Temperature
                                              2) Relative Humidity
                                              3) Wind Speed
                                              4) Solar Elevation
                                              5) Solar Radiation
                                              6) A data table with maxima and minima as well as solar elevation
                                                 gains/losses. 

The only value the user must pass in is the station identifier for the ASOS as a string. 
In this example, we will use KONT (Ontario International Airport in Ontario California)

Now let's make our graphic!
'''
graphical_daily_summary('kont')
# Out:
# Main UCAR THREDDS Server is online. Connecting!
# Downloading...
# C:\Users\edrew\miniconda3\lib\site-packages\firewxpy\data_access.py:3291: UserWarning: Input over 12.566370614359172 radians. Ensure proper units are given.
#   sfc_data = parse_metar_file(metar_text)
# Data retrieved successfully!
# C:\Users\edrew\miniconda3\lib\site-packages\pysolar\solartime.py:113: UserWarning: I don't know about leap seconds after 2023
#   warnings.warn \
# Already Satisfied: Weather Data folder exists.
# f:Weather Data/Daily Weather Summary does not exist.
# Building Daily Weather Summary branch...
# Successfully built new branch to directory!
# KONT Daily Weather Summary Saved to Weather Data/Daily Weather Summary/KONT.png
