# %%
# Import the sawti function from firewxpy
from firewxpy import sawti

# %%
'''
In this example we will make a graphic showing the Santa Ana Wildfire Threat Index (SAWTI) from Rolinski et al. 2016. 
The color the SAWTI outputs depends on the Large Fire Potential (LFP) - Please see Rolinsky et al. 2016 for more information
on how the LFP is calculated. 

All the user is required to do is call the sawti() function and firewxpy does the rest. Please see below. 

'''

sawti()
# Out:
# seaspace_zone1_12292024_12z.csv has been deleted
# seaspace_zone2_12292024_12z.csv has been deleted
# seaspace_zone3_12292024_12z.csv has been deleted
# seaspace_zone4_12292024_12z.csv has been deleted
#
#
# seaspace_zone1_12292024_12z.csv has been downloaded
# seaspace_zone2_12292024_12z.csv has been downloaded
# seaspace_zone3_12292024_12z.csv has been downloaded
# seaspace_zone4_12292024_12z.csv has been downloaded
#
#
# seaspace_zone1_12292024_12z.csv has been converted to a dataframe
# seaspace_zone2_12292024_12z.csv has been converted to a dataframe
# seaspace_zone3_12292024_12z.csv has been converted to a dataframe
# seaspace_zone4_12292024_12z.csv has been converted to a dataframe
#
#
# LFP Zone 1 (Day 1 - Date: 12/30/2024): 1.0
# LFP Zone 1 (Day 2 - Date: 12/31/2024): 1.0
# LFP Zone 1 (Day 3 - Date: 01/01/2025): 3.0
# LFP Zone 1 (Day 4 - Date: 01/02/2025): 4.0
# LFP Zone 1 (Day 5 - Date: 01/03/2025): 2.0
# LFP Zone 1 (Day 6 - Date: 01/04/2025): 1.0
# ...
